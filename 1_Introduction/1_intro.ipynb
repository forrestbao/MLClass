# %%
import random
import sklearn.neural_network
import numpy.random
import ipywidgets
import hashlib

# %%
def generate_data(N):
    g = 9.8
    
    # If using Python's own random number generator
#     Ts = [random.random() for _ in range(N)]
#     Hs = [g*(t**2)/2 for t in Ts]

    # If using Numpy random number generator
    numpy.random.seed(1)
    Ts = numpy.random.rand(N)
    Ts.sort()
    Hs = g*(Ts**2)/2
    
    return Ts, Hs

Ts, Hs = generate_data(2000)

# %%
def test_NN(Ts, Hs, max_iter=200, with_prediction=True):
    NN = sklearn.neural_network.MLPRegressor(
        hidden_layer_sizes=(4,4), 
        activation='tanh', 
        random_state = 1, 
        max_iter=max_iter
        )
    Ts = Ts.reshape(-1, 1) # learned from error
    NN.fit(Ts, Hs)
    predictions = NN.predict(Ts)
    score = NN.score(Ts, Hs)
    return predictions, score
    
max_iter = 200
# print (Ts)
# print (Hs)
test_NN(Ts, Hs, max_iter, with_prediction=False)
# Out:
# /home/forrest/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# (array([ 0.17018527,  3.87478341,  3.38410495, ...,  0.96290458,
#         -0.14897885,  3.84078085]),
#  0.9766919414980015)

# %%
ipywidgets.interact(
    test_NN, 
    Ts=ipywidgets.fixed(Ts), 
    Hs=ipywidgets.fixed(Hs), 
    max_iter = ipywidgets.IntSlider(
        min=50,
        max=1000,
        step=50,
        description='Max # of iterations', 
        layout=ipywidgets.Layout(width='100%')
        ),
    with_prediction = False 
    )
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may help.
# <function __main__.test_NN(Ts, Hs, max_iter=200)>

# %%
def learning_curve(N, max_iter, filename="test.png"):
    """

    N: int, number of data points
    max_iter: int, number of iterations to train the neural network
    filename: str, name of the file to save the plot
    """
    
    # INSERT YOUR CODE BELOW


    # INSERT YOUR CODE ABOVE 

    matplotlib.pyplot.savefig(filename) # save the plot to a file 

    # The return line is for self-checking purposes
    return hashlib.md5(open(filename, "rb").read()).hexdigest()

# %% [markdown]
# # How to plot in Python
#
# First you need to import the `matplotlib.pyplot` library

# %%
import matplotlib.pyplot

# %% [markdown]
# Then you can plot, by passing the X coordinates and Y coordiantes of points to the `matplotlib.pyplot.plot` function

# %%
matplotlib.pyplot.plot(
    [1,2,3], # X coordinates 
    [4,10,6],  # Y coordinates 
    'tab:blue' # color code 
)
matplotlib.pyplot.plot(
    [1,2,3], # X coordinates 
    [2,8,3],  # Y coordinates 
    'tab:orange' # color code
)

# %%
x= numpy.array([1,2,3])
y= numpy.array([1,1,-3])
numpy.dot(x,y)
# Out:
# -6
